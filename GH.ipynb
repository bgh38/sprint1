# %%
#필요한 라이브러리 import
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#광주지역 2018~2020년 기상데이터 로드
data=pd.read_csv('data/기상개황_광주지역__20230327110805.csv',encoding='cp949')
data
# Out:
#     월별(1)      2018      2018.1    2018.2      2018.3    2018.4   2018.5  \
# 0   월별(1)  평균기온 (℃)  평균최고기온 (℃)  최고기온 (℃)  평균최저기온 (℃)  최저기온 (℃)  강수량 (㎜)
# 1      평균      14.6        20.1      38.5        10.3     -11.5   1427.9
# 2      1월      -0.2         4.5      11.4        -3.8     -11.5     38.8
# 3      2월       1.8         7.1      15.9        -2.8     -10.0     22.0
# 4      3월      10.0        16.5      24.8         4.7      -3.1    115.8
# 5      4월      15.1        21.5      30.2         9.7       1.1    127.4
# 6      5월      19.5        25.0      31.1        14.8       7.8     85.4
# 7      6월      23.6        29.5      34.5        19.2      15.7    222.4
# 8      7월      28.3        33.5      38.5        24.5      20.4     84.5
# 9      8월      28.4        33.7      38.5        24.9      20.6    397.1
# 10     9월      21.6        26.3      29.7        18.0      11.6    129.7
# 11    10월      14.5        19.9      25.4        10.1       5.6    125.2
# 12    11월       9.9        15.5      21.0         5.3       0.4     47.2
# 13    12월       3.2         7.8      19.8        -0.6      -7.0     32.4
#
#         2018.6      2018.7        2018.8  ...      2020.6      2020.7  \
# 0   평균상대습도 (%)  최소상대습도 (%)  평균해면기압 (hPa)  ...  평균상대습도 (%)  최소상대습도 (%)
# 1           71           5        1016.9  ...          71           1
# 2           67          14        1024.7  ...          68          13
# 3           54           8        1024.0  ...          67          10
# 4           72           5        1020.2  ...          58           1
# 5           67          11        1016.0  ...          52           5
# 6           74          16        1011.8  ...          73          12
# 7           74          24        1008.0  ...          79          21
# 8           79          36        1008.4  ...          91          49
# 9           78          36        1007.1  ...          89          50
# 10          78          34        1013.0  ...          85          30
# 11          72          19        1019.0  ...          64          12
# 12          70          15        1023.6  ...          63          12
# 13          62           9        1027.3  ...          62           7
#
#           2020.8     2020.9     2020.10   2020.11    2020.12   2020.13  \
# 0   평균해면기압 (hPa)  이슬점온도 (℃)  평균운량 (10%)  일조시간 (h)  최심신적설 (㎝)  평균풍속 (㎧)
# 1         1016.9        8.4         5.6    2225.1       16.9       1.6
# 2         1023.4       -1.5         6.3     136.5          -       1.4
# 3         1025.1       -1.3         4.9     177.0       10.9       1.4
# 4         1018.6       -0.3         4.0     242.0          -       1.7
# 5         1018.4        0.4         3.3     278.1          -       1.8
# 6         1010.7       13.0         6.1     211.3          -       1.7
# 7         1006.6       19.1         6.5     191.4          -       1.6
# 8         1006.7       21.6         8.7      69.5          -       1.5
# 9         1009.2       25.4         6.6     169.8          -       2.2
# 10        1011.8       18.2         6.3     158.7          -       1.5
# 11        1020.5        8.0         4.6     227.6          -       1.2
# 12        1024.9        3.0         4.8     176.7          -       1.4
# 13        1026.6       -4.8         4.8     186.5       16.9       1.4
#
#      2020.14     2020.15
# 0   최대풍속 (㎧)  최대순간풍속 (㎧)
# 1       10.0        19.8
# 2       10.0        19.8
# 3        5.5        10.8
# 4        7.9        15.0
# 5        9.1        14.8
# 6        7.9        12.8
# 7        6.9        10.9
# 8        8.3        13.7
# 9        8.4        16.9
# 10       7.0        14.9
# 11       5.3         9.8
# 12       8.8        13.3
# 13       5.3         9.9
#
# [14 rows x 49 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 49 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   월별(1)    14 non-null     object
#  1   2018     14 non-null     object
#  2   2018.1   14 non-null     object
#  3   2018.2   14 non-null     object
#  4   2018.3   14 non-null     object
#  5   2018.4   14 non-null     object
#  6   2018.5   14 non-null     object
#  7   2018.6   14 non-null     object
#  8   2018.7   14 non-null     object
#  9   2018.8   14 non-null     object
#  10  2018.9   14 non-null     object
#  11  2018.10  14 non-null     object
#  12  2018.11  14 non-null     object
#  13  2018.12  14 non-null     object
#  14  2018.13  14 non-null     object
#  15  2018.14  14 non-null     object
#  16  2018.15  14 non-null     object
#  17  2019     14 non-null     object
#  18  2019.1   14 non-null     object
#  19  2019.2   14 non-null     object
#  20  2019.3   14 non-null     object
#  21  2019.4   14 non-null     object
#  22  2019.5   14 non-null     object
#  23  2019.6   14 non-null     object
#  24  2019.7   14 non-null     object
#  25  2019.8   14 non-null     object
#  26  2019.9   14 non-null     object
#  27  2019.10  14 non-null     object
#  28  2019.11  14 non-null     object
#  29  2019.12  14 non-null     object
#  30  2019.13  14 non-null     object
#  31  2019.14  14 non-null     object
#  32  2019.15  14 non-null     object
#  33  2020     14 non-null     object
#  34  2020.1   14 non-null     object
#  35  2020.2   14 non-null     object
#  36  2020.3   14 non-null     object
#  37  2020.4   14 non-null     object
#  38  2020.5   14 non-null     object
#  39  2020.6   14 non-null     object
#  40  2020.7   14 non-null     object
#  41  2020.8   14 non-null     object
#  42  2020.9   14 non-null     object
#  43  2020.10  14 non-null     object
#  44  2020.11  14 non-null     object
#  45  2020.12  14 non-null     object
#  46  2020.13  14 non-null     object
#  47  2020.14  14 non-null     object
#  48  2020.15  14 non-null     object
# dtypes: object(49)
# memory usage: 5.5+ KB

# %%
#일조시간만 있는 칼럼 선택
hour=data[['2018.11','2019.11','2020.11']]

# %%
hour.columns=['1','2','3']

# %%
#총 일조시간만 있는 행 선택
hour=hour.iloc[[1]]

# %%
#데이터 확인
hour.reset_index(drop=True,inplace=True)
hour
# Out:
#         1       2       3
# 0  2372.5  2290.1  2225.1

# %%
#지역별, 시간별 태양광 발전량 데이터 로드
data=pd.read_csv('data/한국전력거래소_지역별 시간별 태양광 발전량_20211231.csv',encoding='cp949')
data
# Out:
#               거래일자  거래시간    지역       발전량
# 0       2018-01-01     1   강원도     13.680
# 1       2018-01-01     2   강원도      0.000
# 2       2018-01-01     3   강원도     14.400
# 3       2018-01-01     4   강원도      0.000
# 4       2018-01-01     5   강원도      0.000
# ...            ...   ...   ...        ...
# 596083  2021-12-31    20  충청북도  47668.337
# 596084  2021-12-31    21  충청북도  41720.571
# 596085  2021-12-31    22  충청북도  23464.794
# 596086  2021-12-31    23  충청북도   8098.187
# 596087  2021-12-31    24  충청북도   2451.798
#
# [596088 rows x 4 columns]

# %%
#지역이 광주시만 남기고 데이터 리셋
data.drop(data[data['지역']!='광주시'].index,inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
#거래일자에 2018,2019,2020이 들어있는 데이터 분리
data1=data[data['거래일자'].str.contains('2018')]
data2=data[data['거래일자'].str.contains('2019')]
data3=data[data['거래일자'].str.contains('2020')]

# %%
#분리한 데이터에 칼럼이름 수정
data1.columns=['거래일자','거래시간','지역','발전량']
data2.columns=['거래일자','거래시간','지역','발전량']
data3.columns=['거래일자','거래시간','지역','발전량']

# %%
#데이터 프레임에 넣기
d={'연도':['2018','2019','2020'],'총 태양광발전량':[data1['발전량'].sum(),data2['발전량'].sum(),data3['발전량'].sum()]}
sun=pd.DataFrame(data=d)

# %%
sun.astype({'총 태양광발전량':'int'})
# Out:
#      연도  총 태양광발전량
# 0  2018  49377803
# 1  2019  61300463
# 2  2020  69891537

# %%
hour=hour.transpose()

# %%
#일조시간에 연도 칼럼 넣고, 총 일조시간 타입 변경후 데이터 확인
hour['연도']=['2018','2019','2020']
hour.columns=('총 일조시간','연도')
hour.reset_index(drop=True,inplace=True)
hour['총 일조시간']=hour['총 일조시간'].astype(float)
hour
# Out:
#    총 일조시간    연도
# 0  2372.5  2018
# 1  2290.1  2019
# 2  2225.1  2020

# %%
#그래프 표현
plt.figure(figsize=(15,6))
plt.subplot(121)
plt.bar('연도','총 태양광발전량',data=sun,width=0.3)
plt.xlabel('연도')
plt.ylabel('총 태양광발전량')
plt.title('2018~2020년 총 태양광발전량')

plt.figure(figsize=(15,6))
plt.subplot(122)
plt.bar(hour['연도'],hour['총 일조시간'])
plt.xlabel('연도')
plt.ylabel('총 일조시간')
plt.title('2018~2020년 총 일조시간')
plt.ylim(2000,2500)
# Out:
# (2000.0, 2500.0)

# %%
#설비용량 자료 로드
data=pd.read_csv('data/월별 시도별 신재생연계ESS 설비용량 자료(2018_2020).csv',encoding='cp949')
data
# Out:
#        연도   월    지역  태양광 전체 설비용량(MW)  풍력 전체 설비용량  ESS연계 태양광 설비용량  \
# 0    2018   1   경기도            106.8         5.3             2.0
# 1    2018   1   강원도            152.5       323.3            10.5
# 2    2018   1  경상남도            164.1        47.8            17.3
# 3    2018   1  경상북도            256.4       337.0            23.1
# 4    2018   1  전라남도            619.6       206.2            47.6
# ..    ...  ..   ...              ...         ...             ...
# 607  2020  12   광주시             56.6         0.0             6.5
# 608  2020  12   대구시             38.4         0.0             6.9
# 609  2020  12   세종시             20.7         0.0             3.5
# 610  2020  12   울산시             26.4         1.7             4.0
# 611  2020  12   부산시             61.8         0.8             7.1
#
#      ESS연계 풍력 설비용량  태양광ESS 설비용량  풍력ESS 설비용량
# 0              3.0          2.0         0.1
# 1             48.0          8.9         9.0
# 2             14.0         15.4         3.0
# 3             90.3         21.2        23.8
# 4             75.8         40.6         9.3
# ..             ...          ...         ...
# 607            0.0          5.0         0.0
# 608            0.0          6.0         0.0
# 609            0.0          3.3         0.0
# 610            0.0          1.8         0.0
# 611            0.0          6.2         0.0
#
# [612 rows x 9 columns]

# %%
#필요한 칼럼 선택후 저장
data=data[['연도','월','지역','태양광 전체 설비용량(MW)']]
data
# Out:
#        연도   월    지역  태양광 전체 설비용량(MW)
# 0    2018   1   경기도            106.8
# 1    2018   1   강원도            152.5
# 2    2018   1  경상남도            164.1
# 3    2018   1  경상북도            256.4
# 4    2018   1  전라남도            619.6
# ..    ...  ..   ...              ...
# 607  2020  12   광주시             56.6
# 608  2020  12   대구시             38.4
# 609  2020  12   세종시             20.7
# 610  2020  12   울산시             26.4
# 611  2020  12   부산시             61.8
#
# [612 rows x 4 columns]

# %%
#지역이 광주시인 데이터만 표시
data1=data.groupby('지역').get_group('광주시')
data1
# Out:
#        연도   월   지역  태양광 전체 설비용량(MW)
# 12   2018   1  광주시             32.3
# 29   2018   2  광주시             33.3
# 46   2018   3  광주시             35.1
# 63   2018   4  광주시             35.1
# 80   2018   5  광주시             36.9
# 97   2018   6  광주시             40.2
# 114  2018   7  광주시             40.6
# 131  2018   8  광주시             41.7
# 148  2018   9  광주시             41.7
# 165  2018  10  광주시             41.7
# 182  2018  11  광주시             41.9
# 199  2018  12  광주시             42.2
# 216  2019   1  광주시             44.7
# 233  2019   2  광주시             44.9
# 250  2019   3  광주시             45.2
# 267  2019   4  광주시             46.2
# 284  2019   5  광주시             46.2
# 301  2019   6  광주시             46.6
# 318  2019   7  광주시             48.3
# 335  2019   8  광주시             48.9
# 352  2019   9  광주시             50.9
# 369  2019  10  광주시             50.9
# 386  2019  11  광주시             55.2
# 403  2019  12  광주시             55.9
# 420  2020   1  광주시             56.4
# 437  2020   2  광주시             56.4
# 454  2020   3  광주시             56.6
# 471  2020   4  광주시             56.6
# 488  2020   5  광주시             56.6
# 505  2020   6  광주시             56.6
# 522  2020   7  광주시             56.6
# 539  2020   8  광주시             56.6
# 556  2020   9  광주시             56.6
# 573  2020  10  광주시             56.6
# 590  2020  11  광주시             56.6
# 607  2020  12  광주시             56.6

# %%
data1.reset_index(drop=True,inplace=True)

# %%
#연도별 태양광 전체설비용량의 평균을 그래프로 표현
data1=data1.groupby('연도')['태양광 전체 설비용량(MW)'].mean().sort_values(ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(data=data,x='연도', y='태양광 전체 설비용량(MW)')
plt.title('2018~2020년 태양광 전체 설비용량')
plt.show()
